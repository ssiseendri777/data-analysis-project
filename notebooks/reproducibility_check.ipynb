# %%
import sys
import platform
import numpy as np
import pandas as pd
import matplotlib
import sklearn
import shap
import lime
import joblib
from importlib.metadata import version

# %%
print("Python version:", sys.version)
print("Platform:", platform.platform())
print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("Matplotlib version:", matplotlib.__version__)
print("Scikit-learn version:", sklearn.__version__)
print("SHAP version:", shap.__version__)
print("LIME version:", version("lime"))
print("Joblib version:", joblib.__version__)
# Out:
# Python version: 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]
# Platform: Windows-11-10.0.26200-SP0
# NumPy version: 2.3.5
# Pandas version: 2.3.3
# Matplotlib version: 3.10.6
# Scikit-learn version: 1.7.2
# SHAP version: 0.52.0
# LIME version: 0.2.0.1
# Joblib version: 1.5.2

# %%
# Load dataset
data = pd.read_csv("../data/titanic_clean.csv")
X = data.drop("Survived", axis=1)
y = data["Survived"]

# Load models
rf = joblib.load("../models/random_forest_model.pkl")
gb = joblib.load("../models/gradient_boosting_model.pkl")

# Quick check
from sklearn.metrics import accuracy_score

print("Random Forest Accuracy:", accuracy_score(y, rf.predict(X)))
print("Gradient Boosting Accuracy:", accuracy_score(y, gb.predict(X)))
# Out:
# Random Forest Accuracy: 0.920314253647587
# Gradient Boosting Accuracy: 0.9034792368125701
# c:\Users\S SISEENDRI\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\S SISEENDRI\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   warnings.warn(

# %% [markdown]
# ### Project Packaging & Reproducibility
#
# We created a reproducibility notebook to:
# - Print environment details (Python + library versions).
# - Verify that saved models load correctly.
# - Confirm predictions match expected results.
#
# **Conclusion:**
# This ensures anyone can reproduce this project by installing dependencies and running notebooks in a consistent environment.

# %% [markdown]
# ### Dockerization
#
# Running Jupyter inside Docker ensures reproducibility and portability.
# Anyone can now run this project with one command, independent of OS or Python setup.
# This step makes the project professional and shareable.

# %% [markdown]
# ### Render Deployment
# Successfully deployed Dockerized project to Render.
# Jupyter Notebook is now accessible online, ensuring reproducibility and portability.
# This step makes the project shareable with recruiters and collaborators.
#
# Access
#
# Render URL: https://data-analysis-project-i8ns.onrender.com
# Current Jupyter Token: 587e8f6de092cc25a77e5416541c2d36dee3718d83b8419b
